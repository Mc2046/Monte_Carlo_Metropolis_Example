# %%
# -----------------------------------------------------------------
# INTRODUCTION TO MONTECARLO SIMULATION
# Simulation of 2D Ising model
# May 2018 - updated Feb 2023
# -----------------------------------------------------------------
#
# The algorithm is based on Dr Rajesh Singh (Cambridge University) blog with python resources in Physics.
# https://rajeshrinet.github.io/blog/2014/ising-model/
# Adapted by Jordi Faraudo 2018 for teaching purposes
# please look first to the ising_snapshots.py code
#
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

#----------------------------------------------------------------------
##  BLOCK OF FUNCTIONS USED IN THE MAIN CODE
#----------------------------------------------------------------------

#Generation of a random initial state for NxN spins
def initialstate(N):
    ''' generates a random spin configuration for initial condition'''
    state = 2*np.random.randint(2, size=(N,N))-1
    return state

# Here we define the interactions of the model (2D spin Ising model)
# and the solution method (Metropolis Monte Carlo)
def mcmove(config, beta):
    '''Monte Carlo move using Metropolis algorithm '''
    for i in range(N):
        for j in range(N):
                #select random spin from NxN system
                a = np.random.randint(0, N)
                b = np.random.randint(0, N)
                s =  config[a, b]
                #calculate energy cost of this new configuration (the % is for calculation of periodic boundary condition)
                nb = config[(a+1)%N,b] + config[a,(b+1)%N] + config[(a-1)%N,b] + config[a,(b-1)%N]
                # For antiferromagnetism, spins prefer to anti-align, so reverse the sign of the interaction cost
                cost = -2*s*nb # Changed for antiferromagnetism
                #flip spin or not depending on the cost and its Boltzmann factor
                ## (acceptance probability is given by Boltzmann factor with beta = 1/kBT
                if cost < 0:
                    s *= -1
                elif rand() < np.exp(-cost*beta):
                    s *= -1
                config[a, b] = s
    return config

#This function calculates the energy of a given configuration for the plots of Energy as a function of T
def calcEnergy(config):
    '''Energy of a given configuration'''
    energy = 0
    for i in range(len(config)):
        for j in range(len(config)):
            S = config[i,j]
            nb = config[(i+1)%N, j] + config[i,(j+1)%N] + config[(i-1)%N, j] + config[i,(j-1)%N]
            # For antiferromagnetism, spins prefer to anti-align, so reverse the sign of the interaction energy
            energy += nb*S # Changed for antiferromagnetism (original was -nb*S)
    return energy/4.

#This function calculates the magnetization of a given configuration
def calcMag(config):
    '''Magnetization of a given configuration'''
    mag = np.sum(config)
    return mag

#
# MAIN PROGRAM
#
# Initial parameters for calculation
## change the parameter below if you want to simulate a smaller system
nt      = 2**8        # number of temperature points
N       = 2**4        # size of the lattice, N x N
eqSteps = 2**10       # number of MC sweeps for equilibration
mcSteps = 2**10       # number of MC sweeps for calculation

n1, n2  = 1.0/(mcSteps*N*N), 1.0/(mcSteps*mcSteps*N*N)
#Generate a random distribution of temperatures to make an exploration
tm = 2.269;    T=np.random.normal(tm, .64, nt)
T  = T[(T>1.2) & (T<3.8)];    nt = np.size(T)

Energy       = np.zeros(nt);   Magnetization  = np.zeros(nt)
SpecificHeat = np.zeros(nt);   Susceptibility = np.zeros(nt)


#----------------------------------------------------------------------
#  SIMULATION LOOP
#----------------------------------------------------------------------
print('Starting Simulations at ',len(T),' different temperatures.')
for m in range(len(T)):
    E1 = M1 = E2 = M2 = 0
    config = initialstate(N)
    iT=1.0/T[m]
    iT2=iT*iT
    print('Simulation ',m+1,' of',len(T),' at reduced temperature T=',T[m])

    for i in range(eqSteps):         # equilibrate
        mcmove(config, iT)           # Monte Carlo moves

    for i in range(mcSteps):
        mcmove(config, iT)
        Ene = calcEnergy(config)     # calculate the energy
        Mag = calcMag(config)        # calculate the magnetisation

        E1 = E1 + Ene
        M1 = M1 + Mag
        M2 = M2 + Mag*Mag
        E2 = E2 + Ene*Ene

        Energy[m]         = n1*E1
        Magnetization[m]  = n1*M1
        SpecificHeat[m]   = (n1*E2 - n2*E1*E1)*iT2
        Susceptibility[m] = (n1*M2 - n2*M1*M1)*iT

#
# Plot everything
#

f = plt.figure(figsize=(18, 10)); # plot the calculated values

sp =  f.add_subplot(2, 2, 1 );
plt.plot(T, Energy, 'o', color="#A60628");
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy ", fontsize=20);

sp =  f.add_subplot(2, 2, 2 );
plt.plot(T, abs(Magnetization), 'o', color="#348ABD");
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization ", fontsize=20);

sp =  f.add_subplot(2, 2, 3 );
plt.plot(T, SpecificHeat, 'o', color="#A60628");
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat ", fontsize=20);

sp =  f.add_subplot(2, 2, 4 );
plt.plot(T, Susceptibility, 'o', color="#348ABD");
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.show()
# Out:
# Starting Simulations at  243  different temperatures.
# Simulation  1  of 243  at reduced temperature T= 1.8721426362848264
# Simulation  2  of 243  at reduced temperature T= 1.2497394823184973
# Simulation  3  of 243  at reduced temperature T= 1.9953141492868507
# Simulation  4  of 243  at reduced temperature T= 2.245961121385596
# Simulation  5  of 243  at reduced temperature T= 3.3160206561464953
# Simulation  6  of 243  at reduced temperature T= 1.9631788327851871
# Simulation  7  of 243  at reduced temperature T= 1.2923704403390508
# Simulation  8  of 243  at reduced temperature T= 2.0609690033090606
# Simulation  9  of 243  at reduced temperature T= 2.7433330688399544
# Simulation  10  of 243  at reduced temperature T= 2.583767225188405
# Simulation  11  of 243  at reduced temperature T= 1.9564868833304427
# Simulation  12  of 243  at reduced temperature T= 1.8712673073633954
# Simulation  13  of 243  at reduced temperature T= 2.7492851020965654
# Simulation  14  of 243  at reduced temperature T= 2.336912374206777
# Simulation  15  of 243  at reduced temperature T= 1.8928655913979595
# Simulation  16  of 243  at reduced temperature T= 2.7900707461017173
# Simulation  17  of 243  at reduced temperature T= 2.1553907553413527
# Simulation  18  of 243  at reduced temperature T= 2.3353915783477364
# Simulation  19  of 243  at reduced temperature T= 3.0777214233312042
# Simulation  20  of 243  at reduced temperature T= 2.93562540982285
# Simulation  21  of 243  at reduced temperature T= 2.2443600559796373
# Simulation  22  of 243  at reduced temperature T= 3.3755175029933033
# Simulation  23  of 243  at reduced temperature T= 2.8269774345132834
# Simulation  24  of 243  at reduced temperature T= 3.005628681881657
# Simulation  25  of 243  at reduced temperature T= 2.5652114522021625
# Simulation  26  of 243  at reduced temperature T= 1.5524258361918202
# Simulation  27  of 243  at reduced temperature T= 2.9127431733697007
# Simulation  28  of 243  at reduced temperature T= 3.227613359381688
# Simulation  29  of 243  at reduced temperature T= 3.341505475778467
# Simulation  30  of 243  at reduced temperature T= 2.09292777725698
# Simulation  31  of 243  at reduced temperature T= 2.212560955404338
# Simulation  32  of 243  at reduced temperature T= 1.6122807018074892
# Simulation  33  of 243  at reduced temperature T= 3.219182701906118
# Simulation  34  of 243  at reduced temperature T= 1.877374248421666
# Simulation  35  of 243  at reduced temperature T= 2.3793917338980544
# Simulation  36  of 243  at reduced temperature T= 2.540908202848982
# Simulation  37  of 243  at reduced temperature T= 2.4621862026568486
# Simulation  38  of 243  at reduced temperature T= 3.119902825168743
# Simulation  39  of 243  at reduced temperature T= 1.201074527139634
# Simulation  40  of 243  at reduced temperature T= 2.2484155857546644
# Simulation  41  of 243  at reduced temperature T= 3.4945303280322317
# Simulation  42  of 243  at reduced temperature T= 3.4314295265996098
# Simulation  43  of 243  at reduced temperature T= 2.7417106381911136
# Simulation  44  of 243  at reduced temperature T= 2.9109265505005433
# Simulation  45  of 243  at reduced temperature T= 2.8287951625117076
# Simulation  46  of 243  at reduced temperature T= 2.357061038566917
# Simulation  47  of 243  at reduced temperature T= 2.1957965848055356
# Simulation  48  of 243  at reduced temperature T= 2.043874439078186
# Simulation  49  of 243  at reduced temperature T= 1.9183882246298027
# Simulation  50  of 243  at reduced temperature T= 3.4601455544838786
# Simulation  51  of 243  at reduced temperature T= 1.2045130556389811
# Simulation  52  of 243  at reduced temperature T= 2.3571250264623136
# Simulation  53  of 243  at reduced temperature T= 1.4817644239700667
# Simulation  54  of 243  at reduced temperature T= 1.8345039707878605
# Simulation  55  of 243  at reduced temperature T= 2.390020571000529
# Simulation  56  of 243  at reduced temperature T= 1.7609950151456375
# Simulation  57  of 243  at reduced temperature T= 2.931513340337442
# Simulation  58  of 243  at reduced temperature T= 2.3641190004219976
# Simulation  59  of 243  at reduced temperature T= 2.088997309710991
# Simulation  60  of 243  at reduced temperature T= 2.937173254288358
# Simulation  61  of 243  at reduced temperature T= 2.0127965052943217
# Simulation  62  of 243  at reduced temperature T= 2.4476721010688105
# Simulation  63  of 243  at reduced temperature T= 2.0247709438973622
# Simulation  64  of 243  at reduced temperature T= 2.230449299275118
# Simulation  65  of 243  at reduced temperature T= 1.2306051056153346
# Simulation  66  of 243  at reduced temperature T= 1.9286961755257772
# Simulation  67  of 243  at reduced temperature T= 3.1189914853085297
# Simulation  68  of 243  at reduced temperature T= 3.218229104439236
# Simulation  69  of 243  at reduced temperature T= 2.3658021905070417
# Simulation  70  of 243  at reduced temperature T= 2.760302901907311
# Simulation  71  of 243  at reduced temperature T= 1.4551774799540518
# Simulation  72  of 243  at reduced temperature T= 1.3646913519714676
# Simulation  73  of 243  at reduced temperature T= 1.6297942245423782
# Simulation  74  of 243  at reduced temperature T= 2.471916114107585
# Simulation  75  of 243  at reduced temperature T= 2.7151555156811265
# Simulation  76  of 243  at reduced temperature T= 2.2418766831739196
# Simulation  77  of 243  at reduced temperature T= 2.3700232707645186
# Simulation  78  of 243  at reduced temperature T= 2.289804709411501
# Simulation  79  of 243  at reduced temperature T= 1.6235362037812395
# Simulation  80  of 243  at reduced temperature T= 1.6297327911507118
# Simulation  81  of 243  at reduced temperature T= 1.7350688012608655
# Simulation  82  of 243  at reduced temperature T= 2.4957875803796346
# Simulation  83  of 243  at reduced temperature T= 2.4790534021467527
# Simulation  84  of 243  at reduced temperature T= 2.302761283865221
# Simulation  85  of 243  at reduced temperature T= 1.7237998926080245
# Simulation  86  of 243  at reduced temperature T= 2.398658038397215
# Simulation  87  of 243  at reduced temperature T= 2.3036230136358262
# Simulation  88  of 243  at reduced temperature T= 2.2719824586198745
# Simulation  89  of 243  at reduced temperature T= 1.6581009729998768
# Simulation  90  of 243  at reduced temperature T= 3.7004566719436207
# Simulation  91  of 243  at reduced temperature T= 1.9328165226347178
# Simulation  92  of 243  at reduced temperature T= 1.6690739682937168
# Simulation  93  of 243  at reduced temperature T= 1.5730577705414839
# Simulation  94  of 243  at reduced temperature T= 2.619311129417857
# Simulation  95  of 243  at reduced temperature T= 1.5252382577825834
# Simulation  96  of 243  at reduced temperature T= 1.7145495217497588
# Simulation  97  of 243  at reduced temperature T= 3.1096708567220515
# Simulation  98  of 243  at reduced temperature T= 1.5524958611372532
# Simulation  99  of 243  at reduced temperature T= 2.238910427182624
# Simulation  100  of 243  at reduced temperature T= 2.6653106905144233
# Simulation  101  of 243  at reduced temperature T= 1.395628643845459
# Simulation  102  of 243  at reduced temperature T= 2.1810112842556704
# Simulation  103  of 243  at reduced temperature T= 1.7335465197203215
# Simulation  104  of 243  at reduced temperature T= 1.768459394253327
# Simulation  105  of 243  at reduced temperature T= 1.4353683835673339
# Simulation  106  of 243  at reduced temperature T= 2.398758317058368
# Simulation  107  of 243  at reduced temperature T= 2.7951607267815586
# Simulation  108  of 243  at reduced temperature T= 3.090726038455438
# Simulation  109  of 243  at reduced temperature T= 3.064419155767946
# Simulation  110  of 243  at reduced temperature T= 2.115745518070259
# Simulation  111  of 243  at reduced temperature T= 2.2999044626978806
# Simulation  112  of 243  at reduced temperature T= 1.9509795736719786
# Simulation  113  of 243  at reduced temperature T= 2.111574362585278
# Simulation  114  of 243  at reduced temperature T= 2.4772846625649776
# Simulation  115  of 243  at reduced temperature T= 3.0354896831758498
# Simulation  116  of 243  at reduced temperature T= 2.462133869606706
# Simulation  117  of 243  at reduced temperature T= 2.614864602703573
# Simulation  118  of 243  at reduced temperature T= 2.820898228745589
# Simulation  119  of 243  at reduced temperature T= 1.6136353925206728
# Simulation  120  of 243  at reduced temperature T= 2.575748567132047
# Simulation  121  of 243  at reduced temperature T= 2.190580237488529
# Simulation  122  of 243  at reduced temperature T= 2.2059680887563315
# Simulation  123  of 243  at reduced temperature T= 2.7515312488596244
# Simulation  124  of 243  at reduced temperature T= 1.7484438062467813
# Simulation  125  of 243  at reduced temperature T= 2.8499479092148006
# Simulation  126  of 243  at reduced temperature T= 2.1128524749434923
# Simulation  127  of 243  at reduced temperature T= 3.028952852460817
# Simulation  128  of 243  at reduced temperature T= 2.953663447552843
# Simulation  129  of 243  at reduced temperature T= 2.3494664861554693
# Simulation  130  of 243  at reduced temperature T= 1.664050586438087
# Simulation  131  of 243  at reduced temperature T= 1.8332019537067752
# Simulation  132  of 243  at reduced temperature T= 1.9713620959562344
# Simulation  133  of 243  at reduced temperature T= 2.607342665515735
# Simulation  134  of 243  at reduced temperature T= 1.761640111709546
# Simulation  135  of 243  at reduced temperature T= 3.0043128832019996
# Simulation  136  of 243  at reduced temperature T= 1.8538553021175277
# Simulation  137  of 243  at reduced temperature T= 1.9465991065639403
# Simulation  138  of 243  at reduced temperature T= 3.239889571291119
# Simulation  139  of 243  at reduced temperature T= 3.508723122571058
# Simulation  140  of 243  at reduced temperature T= 2.3587664656670224
# Simulation  141  of 243  at reduced temperature T= 1.7952491257570893
# Simulation  142  of 243  at reduced temperature T= 2.5994844852742425
# Simulation  143  of 243  at reduced temperature T= 1.604629492851652
# Simulation  144  of 243  at reduced temperature T= 2.9055144481616413
# Simulation  145  of 243  at reduced temperature T= 2.4361384073476295
# Simulation  146  of 243  at reduced temperature T= 1.404759475927364
# Simulation  147  of 243  at reduced temperature T= 3.580423356736751
# Simulation  148  of 243  at reduced temperature T= 1.394621262474118
# Simulation  149  of 243  at reduced temperature T= 2.575510054531968
# Simulation  150  of 243  at reduced temperature T= 2.8705576364356133
# Simulation  151  of 243  at reduced temperature T= 3.4668177100631574
# Simulation  152  of 243  at reduced temperature T= 2.444862935326621
# Simulation  153  of 243  at reduced temperature T= 2.512384907436281
# Simulation  154  of 243  at reduced temperature T= 2.727402704826873
# Simulation  155  of 243  at reduced temperature T= 2.1022555661801765
# Simulation  156  of 243  at reduced temperature T= 1.6269642147994237
# Simulation  157  of 243  at reduced temperature T= 1.8661751049073971
# Simulation  158  of 243  at reduced temperature T= 2.390819439871425
# Simulation  159  of 243  at reduced temperature T= 1.3578445564491726
# Simulation  160  of 243  at reduced temperature T= 3.383842225769425
# Simulation  161  of 243  at reduced temperature T= 1.6634621313397568
# Simulation  162  of 243  at reduced temperature T= 2.0371467804870442
# Simulation  163  of 243  at reduced temperature T= 3.7528914075008233
# Simulation  164  of 243  at reduced temperature T= 1.8766591574331741
# Simulation  165  of 243  at reduced temperature T= 2.517637504373128
# Simulation  166  of 243  at reduced temperature T= 3.0368551993958697
# Simulation  167  of 243  at reduced temperature T= 1.6436125634522027
# Simulation  168  of 243  at reduced temperature T= 1.6943792634475847
# Simulation  169  of 243  at reduced temperature T= 2.4710204096884847
# Simulation  170  of 243  at reduced temperature T= 2.607207832952659
# Simulation  171  of 243  at reduced temperature T= 1.9379794167371274
# Simulation  172  of 243  at reduced temperature T= 1.7328800151102666
# Simulation  173  of 243  at reduced temperature T= 1.610172729153196
# Simulation  174  of 243  at reduced temperature T= 2.834763879242818
# Simulation  175  of 243  at reduced temperature T= 3.3705798164628398
# Simulation  176  of 243  at reduced temperature T= 2.1723135397297604
# Simulation  177  of 243  at reduced temperature T= 2.047846097909168
# Simulation  178  of 243  at reduced temperature T= 1.2237905185167526
# Simulation  179  of 243  at reduced temperature T= 1.6279279479324442
# Simulation  180  of 243  at reduced temperature T= 1.7023174269881696
# Simulation  181  of 243  at reduced temperature T= 1.8341539980842645
# Simulation  182  of 243  at reduced temperature T= 2.5403644661164124
# Simulation  183  of 243  at reduced temperature T= 1.734007425180968
# Simulation  184  of 243  at reduced temperature T= 3.0453415569931694
# Simulation  185  of 243  at reduced temperature T= 2.7545285224132217
# Simulation  186  of 243  at reduced temperature T= 1.8677394590454786
# Simulation  187  of 243  at reduced temperature T= 2.0280272829245867
# Simulation  188  of 243  at reduced temperature T= 2.2225990631612844
# Simulation  189  of 243  at reduced temperature T= 2.1201274320627173
# Simulation  190  of 243  at reduced temperature T= 2.6553704195991594
# Simulation  191  of 243  at reduced temperature T= 2.3788304416973243
# Simulation  192  of 243  at reduced temperature T= 1.75599944475806
# Simulation  193  of 243  at reduced temperature T= 1.8752596727129225
# Simulation  194  of 243  at reduced temperature T= 2.2112379836337355
# Simulation  195  of 243  at reduced temperature T= 2.168983127385487
# Simulation  196  of 243  at reduced temperature T= 3.202898147506147
# Simulation  197  of 243  at reduced temperature T= 1.485267168158587
# Simulation  198  of 243  at reduced temperature T= 2.9051342464234073
# Simulation  199  of 243  at reduced temperature T= 1.9154614774793195
# Simulation  200  of 243  at reduced temperature T= 2.884134047305589
# Simulation  201  of 243  at reduced temperature T= 2.1110995163869064
# Simulation  202  of 243  at reduced temperature T= 1.2733577183856726
# Simulation  203  of 243  at reduced temperature T= 2.209552716265542
# Simulation  204  of 243  at reduced temperature T= 2.1104531875241084
# Simulation  205  of 243  at reduced temperature T= 2.7598854534860746
# Simulation  206  of 243  at reduced temperature T= 2.2600574272314176
# Simulation  207  of 243  at reduced temperature T= 2.5636933037696528
# Simulation  208  of 243  at reduced temperature T= 1.355105132222295
# Simulation  209  of 243  at reduced temperature T= 2.458845904618148
# Simulation  210  of 243  at reduced temperature T= 2.822330108225692
# Simulation  211  of 243  at reduced temperature T= 2.1566486313594413
# Simulation  212  of 243  at reduced temperature T= 2.4150099544217034
# Simulation  213  of 243  at reduced temperature T= 2.223845526190676
# Simulation  214  of 243  at reduced temperature T= 2.0412197594624133
# Simulation  215  of 243  at reduced temperature T= 1.4710089212261006
# Simulation  216  of 243  at reduced temperature T= 1.6967364878829836
# Simulation  217  of 243  at reduced temperature T= 2.644841280392138
# Simulation  218  of 243  at reduced temperature T= 2.1816446214840233
# Simulation  219  of 243  at reduced temperature T= 1.989329565079443
# Simulation  220  of 243  at reduced temperature T= 2.2391762914513844
# Simulation  221  of 243  at reduced temperature T= 1.7806598596968608
# Simulation  222  of 243  at reduced temperature T= 2.541414434437165
# Simulation  223  of 243  at reduced temperature T= 2.002810886560606
# Simulation  224  of 243  at reduced temperature T= 1.383474679716653
# Simulation  225  of 243  at reduced temperature T= 2.6713625414886715
# Simulation  226  of 243  at reduced temperature T= 2.2299507236323706
# Simulation  227  of 243  at reduced temperature T= 1.2985678740863293
# Simulation  228  of 243  at reduced temperature T= 2.322043102442624
# Simulation  229  of 243  at reduced temperature T= 2.357462398406789
# Simulation  230  of 243  at reduced temperature T= 2.4343938794420477
# Simulation  231  of 243  at reduced temperature T= 2.5306917637467667
# Simulation  232  of 243  at reduced temperature T= 2.1272567355804695
# Simulation  233  of 243  at reduced temperature T= 1.7908902405789169
# Simulation  234  of 243  at reduced temperature T= 1.6869234124907475
# Simulation  235  of 243  at reduced temperature T= 1.6187526082782968
# Simulation  236  of 243  at reduced temperature T= 1.2047516214649983
# Simulation  237  of 243  at reduced temperature T= 2.3601295411544374
# Simulation  238  of 243  at reduced temperature T= 2.9139429870968923
# Simulation  239  of 243  at reduced temperature T= 1.6548829954161355
# Simulation  240  of 243  at reduced temperature T= 2.613249785761444
# Simulation  241  of 243  at reduced temperature T= 1.634060232207403
# Simulation  242  of 243  at reduced temperature T= 2.183313236431092
# Simulation  243  of 243  at reduced temperature T= 2.5380662715560165
